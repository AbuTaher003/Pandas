# %%
import pandas as pd
import numpy as np

# %%
dict1={
    "name": ['taher','messi','dimaria','emi'],
    "marks":[98,99,97,95],
    "city": ['rangpur','rosario','rosario','mar del plata']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks           city
# 0    taher     98        rangpur
# 1    messi     99        rosario
# 2  dimaria     97        rosario
# 3      emi     95  mar del plata

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_no_index.csv',index=False)

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   97.250000
# std     1.707825
# min    95.000000
# 25%    96.500000
# 50%    97.500000
# 75%    98.250000
# max    99.000000

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   97.250000
# std     1.707825
# min    95.000000
# 25%    96.500000
# 50%    97.500000
# 75%    98.250000
# max    99.000000

# %%
taher = pd.read_csv('taher.csv')

# %%
taher
# Out:
#    Train NO  Speed           city
# 0       123     98        rangpur
# 1       124     99        rosario
# 2       125     97        rosario
# 3       126     95  mar del plata

# %%
taher.describe()
# Out:
#          Train NO      Speed
# count    4.000000   4.000000
# mean   124.500000  97.250000
# std      1.290994   1.707825
# min    123.000000  95.000000
# 25%    123.750000  96.500000
# 50%    124.500000  97.500000
# 75%    125.250000  98.250000
# max    126.000000  99.000000

# %%
taher['Speed']
# Out:
# 0    98
# 1    99
# 2    97
# 3    95
# Name: Speed, dtype: int64

# %%
taher['Speed'][0]=50
# Out:
# /var/folders/k_/w_0ddy056_b8jdbw_w07q8lh0000gn/T/ipykernel_25399/245457768.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   taher['Speed'][0]=50
# ...

# %%
 taher
# Out:
#    Train NO  Speed           city
# 0       123     50        rangpur
# 1       124     99        rosario
# 2       125     97        rosario
# 3       126     95  mar del plata

# %%
taher.index=['first','second','third','fourth']

# %%
taher
# Out:
#         Train NO  Speed           city
# first        123     50        rangpur
# second       124     99        rosario
# third        125     97        rosario
# fourth       126     95  mar del plata

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.700769
# 1     0.233699
# 2     0.470079
# 3     0.782863
# 4     0.866657
# 5     0.515449
# 6     0.246055
# 7     0.545191
# 8     0.081465
# 9     0.406687
# 10    0.234994
# 11    0.784765
# 12    0.506219
# 13    0.376789
# 14    0.624235
# 15    0.854114
# 16    0.574111
# 17    0.775488
# 18    0.711103
# 19    0.687177
# 20    0.606994
# 21    0.586757
# 22    0.309944
# 23    0.943261
# 24    0.118373
# 25    0.515997
# 26    0.083908
# 27    0.220178
# 28    0.964352
# 29    0.913372
# 30    0.409076
# 31    0.031985
# 32    0.146659
# 33    0.841707
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 newdf.head()
#
# NameError: name 'newdf' is not defined

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.314292  0.272649  0.395117  0.429929  0.333572
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559

# %%
type(newdf)
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.314292  0.272649  0.395117  0.429929  0.333572
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.loc[0]=1

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0] =
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0] = 1234

# %%
newdf.head()
# Out:
#           A         B         C         D         E       0
# 0      kiru  1.000000  1.000000  1.000000  1.000000  1234.0
# 1  0.337926  0.513933  0.585086  0.364725  0.031106     NaN
# 2  0.071396  0.885554  0.503966  0.951648  0.238882     NaN
# 3  0.645425  0.456438  0.718815  0.948250  0.062247     NaN
# 4  0.987762  0.030402  0.129481  0.448814  0.130559     NaN

# %%
newdf.loc[0,'A']=12345

# %%
newdf.head()
# Out:
#           A         B         C         D         E       0
# 0     12345  1.000000  1.000000  1.000000  1.000000  1234.0
# 1  0.337926  0.513933  0.585086  0.364725  0.031106     NaN
# 2  0.071396  0.885554  0.503966  0.951648  0.238882     NaN
# 3  0.645425  0.456438  0.718815  0.948250  0.062247     NaN
# 4  0.987762  0.030402  0.129481  0.448814  0.130559     NaN

# %%
newdf
# Out:
#             A         B         C         D         E       0
# 0       12345  1.000000  1.000000  1.000000  1.000000  1234.0
# 1    0.337926  0.513933  0.585086  0.364725  0.031106     NaN
# 2    0.071396  0.885554  0.503966  0.951648  0.238882     NaN
# 3    0.645425  0.456438  0.718815  0.948250  0.062247     NaN
# 4    0.987762  0.030402  0.129481  0.448814  0.130559     NaN
# ..        ...       ...       ...       ...       ...     ...
# 329  0.294651  0.033038  0.887150  0.237698  0.905739     NaN
# 330   0.93615  0.179736  0.118941  0.850456  0.741118     NaN
# 331  0.600767  0.762093  0.442357  0.565071  0.097584     NaN
# 332  0.083695  0.990590  0.420669  0.846860  0.868204     NaN
# 333  0.415642  0.359036  0.259651  0.556542  0.243332     NaN
#
# [334 rows x 6 columns]

# %%
newdf.drop('A',axis = 1)
# Out:
#             B         C         D         E       0
# 0    1.000000  1.000000  1.000000  1.000000  1234.0
# 1    0.513933  0.585086  0.364725  0.031106     NaN
# 2    0.885554  0.503966  0.951648  0.238882     NaN
# 3    0.456438  0.718815  0.948250  0.062247     NaN
# 4    0.030402  0.129481  0.448814  0.130559     NaN
# ..        ...       ...       ...       ...     ...
# 329  0.033038  0.887150  0.237698  0.905739     NaN
# 330  0.179736  0.118941  0.850456  0.741118     NaN
# 331  0.762093  0.442357  0.565071  0.097584     NaN
# 332  0.990590  0.420669  0.846860  0.868204     NaN
# 333  0.359036  0.259651  0.556542  0.243332     NaN
#
# [334 rows x 5 columns]

# %%
newdf = newdf.drop(0,axis=1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     12345  1.000000  1.000000  1.000000  1.000000
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.585086  0.364725
# 2  0.503966  0.951648

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     12345  1.000000  1.000000  1.000000  1.000000
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882

# %%
newdf.loc[:,['A','B','C']]
# Out:
#             A         B         C
# 0       12345  1.000000  1.000000
# 1    0.337926  0.513933  0.585086
# 2    0.071396  0.885554  0.503966
# 3    0.645425  0.456438  0.718815
# 4    0.987762  0.030402  0.129481
# ..        ...       ...       ...
# 329  0.294651  0.033038  0.887150
# 330   0.93615  0.179736  0.118941
# 331  0.600767  0.762093  0.442357
# 332  0.083695  0.990590  0.420669
# 333  0.415642  0.359036  0.259651
#
# [334 rows x 3 columns]

# %%
newdf.loc[(newdf['A']< 0.3)]
# Out:
#             A         B         C         D         E
# 2    0.071396  0.885554  0.503966  0.951648  0.238882
# 5     0.28934  0.737928  0.985200  0.574255  0.608295
# 8    0.146712  0.634746  0.561594  0.539983  0.954409
# 10   0.127723  0.411225  0.341887  0.658418  0.266950
# 17   0.107876  0.710263  0.344629  0.093445  0.846867
# ..        ...       ...       ...       ...       ...
# 321  0.183291  0.828880  0.842649  0.412334  0.490967
# 322  0.140538  0.503351  0.640684  0.581709  0.435843
# 323   0.00209  0.319990  0.268228  0.040351  0.412439
# 329  0.294651  0.033038  0.887150  0.237698  0.905739
# 332  0.083695  0.990590  0.420669  0.846860  0.868204
#
# [88 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E
# 2    0.071396  0.885554  0.503966  0.951648  0.238882
# 5     0.28934  0.737928  0.985200  0.574255  0.608295
# 8    0.146712  0.634746  0.561594  0.539983  0.954409
# 10   0.127723  0.411225  0.341887  0.658418  0.266950
# 17   0.107876  0.710263  0.344629  0.093445  0.846867
# ..        ...       ...       ...       ...       ...
# 321  0.183291  0.828880  0.842649  0.412334  0.490967
# 322  0.140538  0.503351  0.640684  0.581709  0.435843
# 323   0.00209  0.319990  0.268228  0.040351  0.412439
# 329  0.294651  0.033038  0.887150  0.237698  0.905739
# 332  0.083695  0.990590  0.420669  0.846860  0.868204
#
# [82 rows x 5 columns]

# %%
newdf.iloc[0,4]
# Out:
# np.float64(1.0)

# %%
value = newdf.iloc[0,4]

# %%
print(value)
# Out:
# 1.0

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     12345  1.000000  1.000000  1.000000  1.000000
# 1  0.337926  0.513933  0.585086  0.364725  0.031106
# 2  0.071396  0.885554  0.503966  0.951648  0.238882
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559

# %%
newdf.iloc[[0,2],[1,2]]
# Out:
#           B         C
# 0  1.000000  1.000000
# 2  0.885554  0.503966

# %%
newdf.drop([1,2],axis=0,inplace=True)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     12345  1.000000  1.000000  1.000000  1.000000
# 3  0.645425  0.456438  0.718815  0.948250  0.062247
# 4  0.987762  0.030402  0.129481  0.448814  0.130559
# 5   0.28934  0.737928  0.985200  0.574255  0.608295
# 6  0.828618  0.182659  0.414052  0.628049  0.189372

# %%
newdf.reset_index(drop =  True, inplace=True)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     12345  1.000000  1.000000  1.000000  1.000000
# 1  0.645425  0.456438  0.718815  0.948250  0.062247
# 2  0.987762  0.030402  0.129481  0.448814  0.130559
# 3   0.28934  0.737928  0.985200  0.574255  0.608295
# 4  0.828618  0.182659  0.414052  0.628049  0.189372

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B']= 56

# %%
newdf.head()
# Out:
#           A   B         C         D         E
# 0     12345  56  1.000000  1.000000  1.000000
# 1  0.645425  56  0.718815  0.948250  0.062247
# 2  0.987762  56  0.129481  0.448814  0.130559
# 3   0.28934  56  0.985200  0.574255  0.608295
# 4  0.828618  56  0.414052  0.628049  0.189372

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:, ['B']] = None
# Out:
# /var/folders/k_/w_0ddy056_b8jdbw_w07q8lh0000gn/T/ipykernel_25399/3746458820.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   newdf.loc[:, ['B']] = None

# %%
df = pd.DataFrame({ "name": ['Alfred', 'Batman', 'Alfred'],
                    "toy": ['mobile', np.nan, 'cycle'],
                    "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#      name     toy       born
# 0  Alfred  mobile        NaT
# 1  Batman     NaN 1940-04-25
# 2  Alfred   cycle        NaT

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
df
# Out:
#      name     toy       born
# 0  Alfred  mobile        NaT
# 1  Batman     NaN 1940-04-25
# 2  Alfred   cycle        NaT

# %%
df.dropna(how='all')
# Out:
#      name     toy       born
# 0  Alfred  mobile        NaT
# 1  Batman     NaN 1940-04-25
# 2  Alfred   cycle        NaT

# %%
df.dropna(how='all', axis = 1)
# Out:
#      name     toy       born
# 0  Alfred  mobile        NaT
# 1  Batman     NaN 1940-04-25
# 2  Alfred   cycle        NaT

# %%
df.drop_duplicates(subset = 'name',keep = 'last')
# Out:
#      name    toy       born
# 1  Batman    NaN 1940-04-25
# 2  Alfred  cycle        NaT

# %%
df.drop_duplicates(subset = 'name',keep = 'first')
# Out:
#      name     toy       born
# 0  Alfred  mobile        NaT
# 1  Batman     NaN 1940-04-25

# %%
df.drop_duplicates(subset = 'name', keep = False)
# Out:
#      name  toy       born
# 1  Batman  NaN 1940-04-25

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 204.0+ bytes

# %%
df['name'].value_counts(dropna = False)
# Out:
# name
# Alfred    2
# Batman    1
# Name: count, dtype: int64

# %%
df
# Out:
#      name     toy       born
# 0  Alfred  mobile        NaT
# 1  Batman     NaN 1940-04-25
# 2  Alfred   cycle        NaT

# %%
df['toy'].value_counts(dropna = False)
# Out:
# toy
# mobile    1
# NaN       1
# cycle     1
# Name: count, dtype: int64

# %%
df['toy'].value_counts(dropna = True)
# Out:
# toy
# mobile    1
# cycle     1
# Name: count, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True   True  False
# 1  True  False   True
# 2  True   True  False

# %%
 data = {
     'column1' : [1,2,3],
     'column2' : [3,4,5]
 }

# %%
dff = pd.DataFrame(data)

# %%
dff
# Out:
#    column1  column2
# 0        1        3
# 1        2        4
# 2        3        5

# %%
dff.describe()
# Out:
#        column1  column2
# count      3.0      3.0
# mean       2.0      4.0
# std        1.0      1.0
# min        1.0      3.0
# 25%        1.5      3.5
# 50%        2.0      4.0
# 75%        2.5      4.5
# max        3.0      5.0

# %%
dff.mean()
# Out:
# column1    2.0
# column2    4.0
# dtype: float64

# %%
dff.corr()
# Out:
#          column1  column2
# column1      1.0      1.0
# column2      1.0      1.0

# %%
dff.count()
dff.max()
# Out:
# column1    3
# column2    5
# dtype: int64

# %%
dff.max()
# Out:
# column1    3
# column2    5
# dtype: int64

# %%
dff.count()
# Out:
# column1    3
# column2    3
# dtype: int64

# %%
dff.min()
# Out:
# column1    1
# column2    3
# dtype: int64

# %%
dff.median()
# Out:
# column1    2.0
# column2    4.0
# dtype: float64

# %%
dff.std()
# Out:
# column1    1.0
# column2    1.0
# dtype: float64

# %%
data = pd.read_excel('data.xlsx', sheet_name='Sheet1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...
